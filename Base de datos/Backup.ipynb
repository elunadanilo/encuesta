-- %% [markdown]
-- # [DbEncuesta]

-- %%
USE [master]
GO

-- %%
/****** Object:  Database [DbEncuesta]    Script Date: 10/10/2021 01:24:30 ******/
CREATE DATABASE [DbEncuesta]
 CONTAINMENT = NONE
 ON  PRIMARY 
( NAME = N'DbEncuesta', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL13.SQLEXPRESS\MSSQL\DATA\DbEncuesta.mdf' , SIZE = 8192KB , MAXSIZE = UNLIMITED, FILEGROWTH = 65536KB )
 LOG ON 
( NAME = N'DbEncuesta_log', FILENAME = N'C:\Program Files\Microsoft SQL Server\MSSQL13.SQLEXPRESS\MSSQL\DATA\DbEncuesta_log.ldf' , SIZE = 8192KB , MAXSIZE = 2048GB , FILEGROWTH = 65536KB )
GO
ALTER DATABASE [DbEncuesta] SET COMPATIBILITY_LEVEL = 130
GO
IF (1 = FULLTEXTSERVICEPROPERTY('IsFullTextInstalled'))
begin
EXEC [DbEncuesta].[dbo].[sp_fulltext_database] @action = 'enable'
end
GO
ALTER DATABASE [DbEncuesta] SET ANSI_NULL_DEFAULT OFF 
GO
ALTER DATABASE [DbEncuesta] SET ANSI_NULLS OFF 
GO
ALTER DATABASE [DbEncuesta] SET ANSI_PADDING OFF 
GO
ALTER DATABASE [DbEncuesta] SET ANSI_WARNINGS OFF 
GO
ALTER DATABASE [DbEncuesta] SET ARITHABORT OFF 
GO
ALTER DATABASE [DbEncuesta] SET AUTO_CLOSE OFF 
GO
ALTER DATABASE [DbEncuesta] SET AUTO_SHRINK OFF 
GO
ALTER DATABASE [DbEncuesta] SET AUTO_UPDATE_STATISTICS ON 
GO
ALTER DATABASE [DbEncuesta] SET CURSOR_CLOSE_ON_COMMIT OFF 
GO
ALTER DATABASE [DbEncuesta] SET CURSOR_DEFAULT  GLOBAL 
GO
ALTER DATABASE [DbEncuesta] SET CONCAT_NULL_YIELDS_NULL OFF 
GO
ALTER DATABASE [DbEncuesta] SET NUMERIC_ROUNDABORT OFF 
GO
ALTER DATABASE [DbEncuesta] SET QUOTED_IDENTIFIER OFF 
GO
ALTER DATABASE [DbEncuesta] SET RECURSIVE_TRIGGERS OFF 
GO
ALTER DATABASE [DbEncuesta] SET  DISABLE_BROKER 
GO
ALTER DATABASE [DbEncuesta] SET AUTO_UPDATE_STATISTICS_ASYNC OFF 
GO
ALTER DATABASE [DbEncuesta] SET DATE_CORRELATION_OPTIMIZATION OFF 
GO
ALTER DATABASE [DbEncuesta] SET TRUSTWORTHY OFF 
GO
ALTER DATABASE [DbEncuesta] SET ALLOW_SNAPSHOT_ISOLATION OFF 
GO
ALTER DATABASE [DbEncuesta] SET PARAMETERIZATION SIMPLE 
GO
ALTER DATABASE [DbEncuesta] SET READ_COMMITTED_SNAPSHOT OFF 
GO
ALTER DATABASE [DbEncuesta] SET HONOR_BROKER_PRIORITY OFF 
GO
ALTER DATABASE [DbEncuesta] SET RECOVERY SIMPLE 
GO
ALTER DATABASE [DbEncuesta] SET  MULTI_USER 
GO
ALTER DATABASE [DbEncuesta] SET PAGE_VERIFY CHECKSUM  
GO
ALTER DATABASE [DbEncuesta] SET DB_CHAINING OFF 
GO
ALTER DATABASE [DbEncuesta] SET FILESTREAM( NON_TRANSACTED_ACCESS = OFF ) 
GO
ALTER DATABASE [DbEncuesta] SET TARGET_RECOVERY_TIME = 60 SECONDS 
GO
ALTER DATABASE [DbEncuesta] SET DELAYED_DURABILITY = DISABLED 
GO
ALTER DATABASE [DbEncuesta] SET QUERY_STORE = OFF
GO
USE [DbEncuesta]
GO
ALTER DATABASE SCOPED CONFIGURATION SET LEGACY_CARDINALITY_ESTIMATION = OFF;
GO
ALTER DATABASE SCOPED CONFIGURATION SET MAXDOP = 0;
GO
ALTER DATABASE SCOPED CONFIGURATION SET PARAMETER_SNIFFING = ON;
GO
ALTER DATABASE SCOPED CONFIGURATION SET QUERY_OPTIMIZER_HOTFIXES = OFF;
GO

-- %% [markdown]
-- # [elunadanilo]

-- %%
USE [DbEncuesta]
GO

-- %%
/****** Object:  User [elunadanilo]    Script Date: 10/10/2021 01:24:30 ******/
CREATE USER [elunadanilo] FOR LOGIN [elunadanilo] WITH DEFAULT_SCHEMA=[dbo]
GO

-- %% [markdown]
-- # [dbo].[TblEncuesta]

-- %%
/****** Object:  Table [dbo].[TblEncuesta]    Script Date: 10/10/2021 01:24:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TblEncuesta](
	[IdEncuesta] [uniqueidentifier] NOT NULL,
	[NombreEncuesta] [varchar](100) NOT NULL,
	[Descripcion] [varchar](150) NOT NULL,
	[FechaCreacion] [datetime] NULL,
 CONSTRAINT [PK_TblEncuesta] PRIMARY KEY CLUSTERED 
(
	[IdEncuesta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TblListadoCampos]

-- %%
/****** Object:  Table [dbo].[TblListadoCampos]    Script Date: 10/10/2021 01:24:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TblListadoCampos](
	[IdListadoCampoEncuesta] [int] IDENTITY(1,1) NOT NULL,
	[Encuesta] [varchar](50) NOT NULL,
	[Nombre] [varchar](150) NOT NULL,
	[Titulo] [varchar](150) NOT NULL,
	[Requerido] [bit] NOT NULL,
	[TipoDeCampo] [varchar](6) NOT NULL,
 CONSTRAINT [PK_TblListadoCampos] PRIMARY KEY CLUSTERED 
(
	[IdListadoCampoEncuesta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TblRespuestas]

-- %%
/****** Object:  Table [dbo].[TblRespuestas]    Script Date: 10/10/2021 01:24:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TblRespuestas](
	[IdRespuesta] [int] IDENTITY(1,1) NOT NULL,
	[IdListadoCampoEncuesta] [int] NOT NULL,
	[Respuesta] [varchar](100) NOT NULL,
 CONSTRAINT [PK_TblRespuestas] PRIMARY KEY CLUSTERED 
(
	[IdRespuesta] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [dbo].[TblUsuarios]

-- %%
/****** Object:  Table [dbo].[TblUsuarios]    Script Date: 10/10/2021 01:24:30 ******/
SET ANSI_NULLS ON
GO
SET QUOTED_IDENTIFIER ON
GO
CREATE TABLE [dbo].[TblUsuarios](
	[IdUsuario] [int] IDENTITY(1,1) NOT NULL,
	[Usuario] [varchar](30) NOT NULL,
	[Password] [varchar](50) NOT NULL,
	[Nombre] [varchar](150) NOT NULL,
	[Correo] [varchar](80) NOT NULL,
	[Administrador] [bit] NOT NULL,
	[Activo] [bit] NOT NULL,
 CONSTRAINT [PK_TblUsuarios] PRIMARY KEY CLUSTERED 
(
	[IdUsuario] ASC
)WITH (PAD_INDEX = OFF, STATISTICS_NORECOMPUTE = OFF, IGNORE_DUP_KEY = OFF, ALLOW_ROW_LOCKS = ON, ALLOW_PAGE_LOCKS = ON) ON [PRIMARY]
) ON [PRIMARY]
GO

-- %% [markdown]
-- # [DF_TblEncuesta_IdEncuesta]

-- %%
ALTER TABLE [dbo].[TblEncuesta] ADD  CONSTRAINT [DF_TblEncuesta_IdEncuesta]  DEFAULT (newid()) FOR [IdEncuesta]
GO

-- %% [markdown]
-- # [DF_TblEncuesta_FechaCreacion]

-- %%
ALTER TABLE [dbo].[TblEncuesta] ADD  CONSTRAINT [DF_TblEncuesta_FechaCreacion]  DEFAULT (getdate()) FOR [FechaCreacion]
GO

-- %% [markdown]
-- # [DF_TblListadoCampos_Requerido]

-- %%
ALTER TABLE [dbo].[TblListadoCampos] ADD  CONSTRAINT [DF_TblListadoCampos_Requerido]  DEFAULT ((0)) FOR [Requerido]
GO

-- %% [markdown]
-- # [DF_TblUsuarios_Administrador]

-- %%
ALTER TABLE [dbo].[TblUsuarios] ADD  CONSTRAINT [DF_TblUsuarios_Administrador]  DEFAULT ((0)) FOR [Administrador]
GO

-- %% [markdown]
-- # [DF_TblUsuarios_Activo]

-- %%
ALTER TABLE [dbo].[TblUsuarios] ADD  CONSTRAINT [DF_TblUsuarios_Activo]  DEFAULT ((0)) FOR [Activo]
GO

-- %% [markdown]
-- # [DbEncuesta]

-- %%
USE [master]
GO

-- %%
ALTER DATABASE [DbEncuesta] SET  READ_WRITE 
GO
